# %% [markdown]
# # Name: Aniruddh Kulkarni

# %% [markdown]
# # Roll No: I081

# %% [markdown]
# # Batch: C3

# %% [markdown]
# # Semester: III Semester

# %% [markdown]
# # Branch: CS (AI)

# %% [markdown]
# # Date of Experiment: 24-07-2021

# %% [markdown]
# # AIM:
#
# 1.  Write a program to generate PDF of uniform distribution function.
#
# 2.  Write a program to generate PDF of Normal distribution function.
#
# 3.  Write a program to generate PDF of Gamma distribution function.
#
# 4.  Write a program to generate PDF of Exponential distribution function.
#
# 5.  Write a program to generate PDF of Binomial distribution function.
#
# 6.  Write a program to generate PDF of Poisson’s distribution function.

# %% [markdown]
# # 1

# %% [markdown]
# # write a program to generate PDF of uniform distribution function
# $$f(x)=\begin{cases} \frac{1}{b-a} & \text{ ; } a\leq x\leq b \\ 0& \text{ ; } otherwise \end{cases} $$

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import uniform
import seaborn as sns

# %%
a = 10
b = 30
n = 10000
fx_uniform = uniform.rvs(loc=a,scale=b-a,size=n)

ax = sns.distplot(fx_uniform)
ax.set(xlabel='x-->',ylabel='Frequency',title='Uniform Distribution')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'x-->'),
#  Text(0, 0.5, 'Frequency'),
#  Text(0.5, 1.0, 'Uniform Distribution')]

# %% [markdown]
# # 2

# %% [markdown]
# # Write a program to generate PDF of Normal Distribution function
# $$f(x) = \frac{1}{2 \pi \sigma^{2}}.e^{\frac{-(x-\mu)^{2}}{2\sigma^{2}}}$$

# %%
from scipy.stats import norm
mean = 0
std = 1
n = 10000
fx_normal = norm.rvs(size = n,loc = mean,scale = std)

bx = sns.distplot(fx_normal)
bx.set(xlabel = 'x-->',ylabel = 'Frequency-->',title = 'Normal Distribution')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'x-->'),
#  Text(0, 0.5, 'Frequency-->'),
#  Text(0.5, 1.0, 'Normal Distribution')]

# %% [markdown]
# # 3

# %% [markdown]
# # Write a program to generate PDF of Gamma distribution function.
# $$f(x) = \frac{\beta^{\alpha}\; x^{\alpha-1}\;e^{-\beta x} }{\Gamma (a)}$$

# %%
from scipy.stats import gamma
mean = 0
std = 1
n = 10000
fx_gm = gamma.rvs(size = n,a = 5,loc = mean,scale = std)

bx = sns.distplot(fx_gm)
bx.set(xlabel = 'x-->',ylabel = 'Frequency-->',title = 'Gamma Distribution')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'x-->'),
#  Text(0, 0.5, 'Frequency-->'),
#  Text(0.5, 1.0, 'Gamma Distribution')]

# %% [markdown]
# # 4

# %% [markdown]
# # Write a program to generate PDF of Exponential distribution function.
# $$f(x) = \begin{cases} \lambda e^{-\lambda x} & \text{ if } x\geq 0 \\ 0 & \text{ if } x<0 \end{cases}$$

# %%
from scipy.stats import expon
mean = 0
std = 1
n = 10000
fx_ex = expon.rvs(size = n,loc = mean,scale = std)

bx = sns.distplot(fx_ex)
bx.set(xlabel = 'x-->',ylabel = 'Frequency-->',title = 'Exponential Distribution')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'x-->'),
#  Text(0, 0.5, 'Frequency-->'),
#  Text(0.5, 1.0, 'Exponential Distribution')]

# %% [markdown]
# # 5

# %% [markdown]
# # Write a program to generate PDF of Binomial distribution function.
# $$f(x) = _{x}^{n}\textrm{C}\; p^{x} (1-p)^{n-x}$$

# %%
from scipy.stats import binom
fx_bi = binom.rvs(size = 10000,n = 10,p = 0.8)

bx = sns.distplot(fx_bi)
bx.set(xlabel = 'x-->',ylabel = 'Frequency-->',title = 'Binomial Distribution')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'x-->'),
#  Text(0, 0.5, 'Frequency-->'),
#  Text(0.5, 1.0, 'Binomial Distribution')]

# %% [markdown]
# # 6

# %% [markdown]
# # Write a program to generate PDF of Poisson’s distribution function.
# $$P(x)=\frac{e^{-\lambda}\;\;\lambda^{x}}{x!}​​$$

# %%
from scipy.stats import poisson
fx_pi = poisson.rvs(size = 10000,mu = 3)

bx = sns.distplot(fx_pi)
bx.set(xlabel = 'x-->',ylabel = 'Frequency-->',title = 'Poisson Distribution')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'x-->'),
#  Text(0, 0.5, 'Frequency-->'),
#  Text(0.5, 1.0, 'Poisson Distribution')]

# %% [markdown]
# # Conclusion
# I learnt about various distributions like uniform, normal, gamma, exponential, binomial, poisson distribution and also implemented it in python
